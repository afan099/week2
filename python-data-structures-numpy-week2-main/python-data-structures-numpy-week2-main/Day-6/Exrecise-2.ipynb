# %%
# Generating Random Numbers

import random
import numpy as np

random_numbers = np.random.rand(5)

print("Random Numbers:", random_numbers)
# Out:
# Random Numbers: [0.24313171 0.35929537 0.72456135 0.08087694 0.80327298]
