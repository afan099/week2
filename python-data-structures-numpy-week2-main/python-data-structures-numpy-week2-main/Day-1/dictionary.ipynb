# %%
student = {
    "name": "Aadesh",
    "age": 20,
    "grade": "A"
}

print("Student Information:", student)

print("Student Name:", student["name"])
print("Student Grade:", student["grade"])
# Out:
# Student Information: {'name': 'Aadesh', 'age': 20, 'grade': 'A'}
# Student Name: Aadesh
# Student Grade: A
