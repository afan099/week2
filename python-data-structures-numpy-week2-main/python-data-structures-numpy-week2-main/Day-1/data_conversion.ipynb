# %%
# List -> Set
numbers_list = [1, 2, 2, 3, 4, 4]

numbers_set = set(numbers_list)

print("List:", numbers_list)
print("Converted Set:", numbers_set)

# Tuple -> List
numbers_tuple = (5, 10, 15)

numbers_list = list(numbers_tuple)

print("Tuple:", numbers_tuple)
print("Converted List:", numbers_list)

# Set -> List
numbers_set = {7, 8, 9}

numbers_list = list(numbers_set)

print("Set:", numbers_set)
print("Converted List:", numbers_list)
# Out:
# List: [1, 2, 2, 3, 4, 4]
# Converted Set: {1, 2, 3, 4}
# Tuple: (5, 10, 15)
# Converted List: [5, 10, 15]
# Set: {8, 9, 7}
# Converted List: [8, 9, 7]
